# %% [markdown]
# # EDA PROJECT

# %% [markdown]
# # Load all necessary libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#import the datasets
calendar = pd.read_csv('calendar.csv')
listing = pd.read_csv('listings.csv')
reviews = pd.read_csv('reviews.csv')

# %%
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0    50408806  2021-07-17         f  $150.00        $150.00             3.0
# 1    50408806  2021-07-18         f  $150.00        $150.00             3.0
# 2    50408806  2021-07-19         t  $150.00        $150.00             3.0
# 3    50408806  2021-07-20         t  $150.00        $150.00             3.0
# 4    50408806  2021-07-21         t  $150.00        $150.00             3.0
#
#    maximum_nights
# 0            45.0
# 1            45.0
# 2            45.0
# 3            45.0
# 4            45.0

# %%
listing.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  10595  https://www.airbnb.com/rooms/10595  20210715154418   2021-07-17
# 1  10990  https://www.airbnb.com/rooms/10990  20210715154418   2021-07-17
# 2  10993  https://www.airbnb.com/rooms/10993  20210715154418   2021-07-17
# 3  10995  https://www.airbnb.com/rooms/10995  20210715154418   2021-07-17
# 4  27262  https://www.airbnb.com/rooms/27262  20210715154418   2021-07-17
#
#                                              name  \
# 0             96m2, 3BR, 2BA, Metro, WI-FI etc...
# 1    Athens Quality Apartments - Deluxe Apartment
# 2              Athens Quality Apartments - Studio
# 3  AQA-No2 1-bedroom, smart tv, fiber connection,
# 4              54m2, 1-br, cable tv, wi-fi, metro
#
#                                          description  \
# 0  Athens Furnished Apartment No6 is 3-bedroom ap...
# 1  Athens Quality Apartments - Deluxe apartment i...
# 2  The Studio is an <br />-excellent located <br ...
# 3  AQA No2 is 1-bedroom apartment (47m2), on the ...
# 4  Big 1-bedroom apartment that can accommodate 4...
#
#                                neighborhood_overview  \
# 0  Ampelokipi district is nice multinational and ...
# 1  Ampelokipi district is nice multinational and ...
# 2  Ampelokipi district is nice multinational and ...
# 3  Ampelokipi district is nice multinational and ...
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f7e19a44-5afe...    37177
# 1  https://a0.muscache.com/pictures/8645179/c1728...    37177
# 2  https://a0.muscache.com/pictures/107309527/848...    37177
# 3  https://a0.muscache.com/pictures/6a565613-aaa3...    37177
# 4  https://a0.muscache.com/pictures/8651803/4b82b...    37177
#
#                                   host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/37177  ...                        4.86
# 1  https://www.airbnb.com/users/show/37177  ...                        4.92
# 2  https://www.airbnb.com/users/show/37177  ...                        4.97
# 3  https://www.airbnb.com/users/show/37177  ...                        4.87
# 4  https://www.airbnb.com/users/show/37177  ...                        5.00
#
#   review_scores_location review_scores_value      license instant_bookable  \
# 0                   4.52                4.69  00000957568                t
# 1                   4.83                4.81  00001070920                t
# 2                   4.84                4.83  00000957080                t
# 3                   4.77                4.77  00000957422                t
# 4                   4.69                4.63  00000957579                t
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              6                                           6
# 1                              6                                           6
# 2                              6                                           6
# 3                              6                                           6
# 4                              6                                           6
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.39
# 1                                           0              0.70
# 2                                           0              0.91
# 3                                           0              0.35
# 4                                           0              0.25
#
# [5 rows x 74 columns]

# %%
reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0       10595    271535  2011-05-20       189305        Pamela
# 1       10595   1994237  2012-08-15       289831        Andrey
# 2       10595   4678609  2013-05-20      2635427         Ahmet
# 3       10595  12502994  2014-05-04      2422327          Hema
# 4       10595  19482948  2014-09-13      6737784       Mariana
#
#                                             comments
# 0  The apartment was wonderful, fully equiped, be...
# 1  Emmanouil was an excellent host. He provided u...
# 2  Manos is a very good host, he is kind and help...
# 3  Our stay in Emmanouil home was comfortable, qu...
# 4  Fantastic accommodation very well located to v...

# %%
#  calender dataset
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3518603 entries, 0 to 3518602
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 187.9+ MB

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9640 entries, 0 to 9639
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            9640 non-null   int64
#  1   listing_url                                   9640 non-null   object
#  2   scrape_id                                     9640 non-null   int64
#  3   last_scraped                                  9640 non-null   object
#  4   name                                          9637 non-null   object
#  5   description                                   9532 non-null   object
#  6   neighborhood_overview                         6720 non-null   object
#  7   picture_url                                   9640 non-null   object
#  8   host_id                                       9640 non-null   int64
#  9   host_url                                      9640 non-null   object
#  10  host_name                                     9627 non-null   object
#  11  host_since                                    9627 non-null   object
#  12  host_location                                 9611 non-null   object
#  13  host_about                                    5442 non-null   object
#  14  host_response_time                            7769 non-null   object
#  15  host_response_rate                            7769 non-null   object
#  16  host_acceptance_rate                          7574 non-null   object
#  17  host_is_superhost                             9627 non-null   object
#  18  host_thumbnail_url                            9627 non-null   object
#  19  host_picture_url                              9627 non-null   object
#  20  host_neighbourhood                            7320 non-null   object
#  21  host_listings_count                           9627 non-null   float64
#  22  host_total_listings_count                     9627 non-null   float64
#  23  host_verifications                            9640 non-null   object
#  24  host_has_profile_pic                          9627 non-null   object
#  25  host_identity_verified                        9627 non-null   object
#  26  neighbourhood                                 6720 non-null   object
#  27  neighbourhood_cleansed                        9640 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      9640 non-null   float64
#  30  longitude                                     9640 non-null   float64
#  31  property_type                                 9640 non-null   object
#  32  room_type                                     9640 non-null   object
#  33  accommodates                                  9640 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                9639 non-null   object
#  36  bedrooms                                      8826 non-null   float64
#  37  beds                                          9574 non-null   float64
#  38  amenities                                     9640 non-null   object
#  39  price                                         9640 non-null   object
#  40  minimum_nights                                9640 non-null   int64
#  41  maximum_nights                                9640 non-null   int64
#  42  minimum_minimum_nights                        9640 non-null   int64
#  43  maximum_minimum_nights                        9640 non-null   int64
#  44  minimum_maximum_nights                        9640 non-null   int64
#  45  maximum_maximum_nights                        9640 non-null   int64
#  46  minimum_nights_avg_ntm                        9640 non-null   float64
#  47  maximum_nights_avg_ntm                        9640 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              9640 non-null   object
#  50  availability_30                               9640 non-null   int64
#  51  availability_60                               9640 non-null   int64
#  52  availability_90                               9640 non-null   int64
#  53  availability_365                              9640 non-null   int64
#  54  calendar_last_scraped                         9640 non-null   object
#  55  number_of_reviews                             9640 non-null   int64
#  56  number_of_reviews_ltm                         9640 non-null   int64
#  57  number_of_reviews_l30d                        9640 non-null   int64
#  58  first_review                                  7463 non-null   object
#  59  last_review                                   7463 non-null   object
#  60  review_scores_rating                          7463 non-null   float64
#  61  review_scores_accuracy                        7423 non-null   float64
#  62  review_scores_cleanliness                     7423 non-null   float64
#  63  review_scores_checkin                         7422 non-null   float64
#  64  review_scores_communication                   7423 non-null   float64
#  65  review_scores_location                        7422 non-null   float64
#  66  review_scores_value                           7421 non-null   float64
#  67  license                                       7276 non-null   object
#  68  instant_bookable                              9640 non-null   object
#  69  calculated_host_listings_count                9640 non-null   int64
#  70  calculated_host_listings_count_entire_homes   9640 non-null   int64
#  71  calculated_host_listings_count_private_rooms  9640 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   9640 non-null   int64
#  73  reviews_per_month                             7463 non-null   float64
# dtypes: float64(19), int64(21), object(34)
# memory usage: 5.4+ MB

# %%
# review dataset
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366678 entries, 0 to 366677
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     366678 non-null  int64
#  1   id             366678 non-null  int64
#  2   date           366678 non-null  object
#  3   reviewer_id    366678 non-null  int64
#  4   reviewer_name  366678 non-null  object
#  5   comments       366325 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 16.8+ MB

# %%
# Fill missing price with zero
calendar['price'].fillna('$0', inplace=True)
# Remove commas in price
calendar['price'] = calendar['price'].apply(lambda x:''.join(x.split(',')))
# Convert price to numeric data
calendar['price'] = calendar['price'].apply(lambda x:float(x.split('$')[1]))
calendar.head(4)
# Out:
#    listing_id        date available  price adjusted_price  minimum_nights  \
# 0    50408806  2021-07-17         f  150.0        $150.00             3.0
# 1    50408806  2021-07-18         f  150.0        $150.00             3.0
# 2    50408806  2021-07-19         t  150.0        $150.00             3.0
# 3    50408806  2021-07-20         t  150.0        $150.00             3.0
#
#    maximum_nights
# 0            45.0
# 1            45.0
# 2            45.0
# 3            45.0

# %%
# Convert available to numeric data
calendar['available'] = calendar['available'].apply(lambda x:1 if x=='t' else 0)
# Split month into a separate column
calendar['month'] = calendar['date'].apply(lambda x: x.split('-')[1])
calendar.head()
# Out:
#    listing_id        date  available  price adjusted_price  minimum_nights  \
# 0    50408806  2021-07-17          0  150.0        $150.00             3.0
# 1    50408806  2021-07-18          0  150.0        $150.00             3.0
# 2    50408806  2021-07-19          1  150.0        $150.00             3.0
# 3    50408806  2021-07-20          1  150.0        $150.00             3.0
# 4    50408806  2021-07-21          1  150.0        $150.00             3.0
#
#    maximum_nights month
# 0            45.0    07
# 1            45.0    07
# 2            45.0    07
# 3            45.0    07
# 4            45.0    07

# %%
# check if the number of listings was the same every day
calendar.groupby(['listing_id']).count()['date'].unique()
# Out:
# array([365, 366, 367], dtype=int64)

# %%
# Groupby by month sum
calendar_month_sum= calendar.groupby(["month"]).sum()
calendar_month_sum.drop(["listing_id"],axis=1,inplace=True)
calendar_month_sum.reset_index(inplace=True)
calendar_month_sum
# Out:
#    month  available       price  minimum_nights  maximum_nights
# 0     01     195018  66197352.0       1401175.0     270351381.0
# 1     02     167232  62046511.0       1263736.0     244178722.0
# 2     03     186902  68586400.0       1393781.0     270360007.0
# 3     04     171104  73289100.0       1350152.0     261736592.0
# 4     05     170854  78451107.0       1390031.0     270536660.0
# 5     06     166107  77735098.0       1344249.0     261755865.0
# 6     07     128243  54338736.0       1486112.0     270248915.0
# 7     08     144169  27861648.0       1420113.0     269706011.0
# 8     09     186914  26642323.0       1347163.0     261266839.0
# 9     10     211713  29926168.0       1374227.0     270311509.0
# 10    11     209471  31742439.0       1327724.0     261388731.0
# 11    12     220137  33743629.0       1372043.0     270171297.0

# %% [markdown]
# ## Plot a line graph of "Availability VS Month"

# %%
plt.figure(figsize=(20, 10))
x = calendar_month_sum["month"]
y = calendar_month_sum["available"]
plt.plot(x,y,linewidth=3.0)
plt.xlabel('Month')
plt.ylabel('Availability')
plt.title('Month vs Availablity')
plt.grid(True)
plt.show()

# %%
# Groupby by month average
calendar_month_sum['average price'] = calendar_month_sum['price']/calendar_month_sum['available']
calendar_month_sum
# Out:
#    month  available       price  minimum_nights  maximum_nights  average price
# 0     01     195018  66197352.0       1401175.0     270351381.0     339.442267
# 1     02     167232  62046511.0       1263736.0     244178722.0     371.020564
# 2     03     186902  68586400.0       1393781.0     270360007.0     366.964505
# 3     04     171104  73289100.0       1350152.0     261736592.0     428.330723
# 4     05     170854  78451107.0       1390031.0     270536660.0     459.170444
# 5     06     166107  77735098.0       1344249.0     261755865.0     467.982072
# 6     07     128243  54338736.0       1486112.0     270248915.0     423.716975
# 7     08     144169  27861648.0       1420113.0     269706011.0     193.256858
# 8     09     186914  26642323.0       1347163.0     261266839.0     142.537868
# 9     10     211713  29926168.0       1374227.0     270311509.0     141.352529
# 10    11     209471  31742439.0       1327724.0     261388731.0     151.536198
# 11    12     220137  33743629.0       1372043.0     270171297.0     153.284677

# %% [markdown]
# ## Plot a line graph of "Average Price VS Month"

# %%
plt.figure(figsize=(20, 10))
x = calendar_month_sum['month']
y = calendar_month_sum['average price']
plt.plot(x,y,linewidth=3.0)
plt.xlabel('Month')
plt.ylabel('Average Price')
plt.title('Month vs Average Price')

plt.grid(True)
plt.show()

# %%
listing['price']
# Out:
# 0       $100.00
# 1        $59.00
# 2        $45.00
# 3        $60.00
# 4        $69.00
#          ...
# 9635     $50.00
# 9636     $18.00
# 9637     $60.00
# 9638    $123.00
# 9639    $150.00
# Name: price, Length: 9640, dtype: object

# %%
calendar['price'] = calendar['price'].replace('[\$\,\.]', '', regex=True).astype(float)/100
calendar['price']
# Out:
# 0          1.50
# 1          1.50
# 2          1.50
# 3          1.50
# 4          1.50
#            ...
# 3518598    0.78
# 3518599    0.78
# 3518600    0.78
# 3518601    0.78
# 3518602    0.78
# Name: price, Length: 3518603, dtype: float64

# %%
calendar = calendar[calendar['available']=='t']
set(calendar['available'])
# Out:
# set()

# %%
# Histogram of booking price distribution
plt.rcParams["figure.figsize"] = (15,5)
sns.distplot(calendar['price'] , color='orange')
x = [0,10,20,50,100,200,300 ]
plt.xticks(x)
plt.title('Histogram of booking price distribution')
plt.xlabel('Booking price')
plt.show()

# %%
calendar['price'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: price, dtype: float64

# %%
listing['price'] = listing['price'].replace('[\$\,\.]', '', regex=True).astype(float)/100
listing['price']
# Out:
# 0       100.0
# 1        59.0
# 2        45.0
# 3        60.0
# 4        69.0
#         ...
# 9635     50.0
# 9636     18.0
# 9637     60.0
# 9638    123.0
# 9639    150.0
# Name: price, Length: 9640, dtype: float64

# %%
# mean price per Property type
x = pd.DataFrame(listing.groupby('property_type')['price'].mean().sort_values(ascending=False))
x = x.reset_index()

sns.barplot(x = 'property_type',
            y = 'price',
            data = x)
plt.xticks(rotation=90)
plt.xlabel('Property type')
plt.ylabel('Mean Price')
plt.show()

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9640 entries, 0 to 9639
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            9640 non-null   int64
#  1   listing_url                                   9640 non-null   object
#  2   scrape_id                                     9640 non-null   int64
#  3   last_scraped                                  9640 non-null   object
#  4   name                                          9637 non-null   object
#  5   description                                   9532 non-null   object
#  6   neighborhood_overview                         6720 non-null   object
#  7   picture_url                                   9640 non-null   object
#  8   host_id                                       9640 non-null   int64
#  9   host_url                                      9640 non-null   object
#  10  host_name                                     9627 non-null   object
#  11  host_since                                    9627 non-null   object
#  12  host_location                                 9611 non-null   object
#  13  host_about                                    5442 non-null   object
#  14  host_response_time                            7769 non-null   object
#  15  host_response_rate                            7769 non-null   object
#  16  host_acceptance_rate                          7574 non-null   object
#  17  host_is_superhost                             9627 non-null   object
#  18  host_thumbnail_url                            9627 non-null   object
#  19  host_picture_url                              9627 non-null   object
#  20  host_neighbourhood                            7320 non-null   object
#  21  host_listings_count                           9627 non-null   float64
#  22  host_total_listings_count                     9627 non-null   float64
#  23  host_verifications                            9640 non-null   object
#  24  host_has_profile_pic                          9627 non-null   object
#  25  host_identity_verified                        9627 non-null   object
#  26  neighbourhood                                 6720 non-null   object
#  27  neighbourhood_cleansed                        9640 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      9640 non-null   float64
#  30  longitude                                     9640 non-null   float64
#  31  property_type                                 9640 non-null   object
#  32  room_type                                     9640 non-null   object
#  33  accommodates                                  9640 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                9639 non-null   object
#  36  bedrooms                                      8826 non-null   float64
#  37  beds                                          9574 non-null   float64
#  38  amenities                                     9640 non-null   object
#  39  price                                         9640 non-null   float64
#  40  minimum_nights                                9640 non-null   int64
#  41  maximum_nights                                9640 non-null   int64
#  42  minimum_minimum_nights                        9640 non-null   int64
#  43  maximum_minimum_nights                        9640 non-null   int64
#  44  minimum_maximum_nights                        9640 non-null   int64
#  45  maximum_maximum_nights                        9640 non-null   int64
#  46  minimum_nights_avg_ntm                        9640 non-null   float64
#  47  maximum_nights_avg_ntm                        9640 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              9640 non-null   object
#  50  availability_30                               9640 non-null   int64
#  51  availability_60                               9640 non-null   int64
#  52  availability_90                               9640 non-null   int64
#  53  availability_365                              9640 non-null   int64
#  54  calendar_last_scraped                         9640 non-null   object
#  55  number_of_reviews                             9640 non-null   int64
#  56  number_of_reviews_ltm                         9640 non-null   int64
#  57  number_of_reviews_l30d                        9640 non-null   int64
#  58  first_review                                  7463 non-null   object
#  59  last_review                                   7463 non-null   object
#  60  review_scores_rating                          7463 non-null   float64
#  61  review_scores_accuracy                        7423 non-null   float64
#  62  review_scores_cleanliness                     7423 non-null   float64
#  63  review_scores_checkin                         7422 non-null   float64
#  64  review_scores_communication                   7423 non-null   float64
#  65  review_scores_location                        7422 non-null   float64
#  66  review_scores_value                           7421 non-null   float64
#  67  license                                       7276 non-null   object
#  68  instant_bookable                              9640 non-null   object
#  69  calculated_host_listings_count                9640 non-null   int64
#  70  calculated_host_listings_count_entire_homes   9640 non-null   int64
#  71  calculated_host_listings_count_private_rooms  9640 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   9640 non-null   int64
#  73  reviews_per_month                             7463 non-null   float64
# dtypes: float64(20), int64(21), object(33)
# memory usage: 5.4+ MB

# %%
listing.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  10595  https://www.airbnb.com/rooms/10595  20210715154418   2021-07-17
# 1  10990  https://www.airbnb.com/rooms/10990  20210715154418   2021-07-17
# 2  10993  https://www.airbnb.com/rooms/10993  20210715154418   2021-07-17
# 3  10995  https://www.airbnb.com/rooms/10995  20210715154418   2021-07-17
# 4  27262  https://www.airbnb.com/rooms/27262  20210715154418   2021-07-17
#
#                                              name  \
# 0             96m2, 3BR, 2BA, Metro, WI-FI etc...
# 1    Athens Quality Apartments - Deluxe Apartment
# 2              Athens Quality Apartments - Studio
# 3  AQA-No2 1-bedroom, smart tv, fiber connection,
# 4              54m2, 1-br, cable tv, wi-fi, metro
#
#                                          description  \
# 0  Athens Furnished Apartment No6 is 3-bedroom ap...
# 1  Athens Quality Apartments - Deluxe apartment i...
# 2  The Studio is an <br />-excellent located <br ...
# 3  AQA No2 is 1-bedroom apartment (47m2), on the ...
# 4  Big 1-bedroom apartment that can accommodate 4...
#
#                                neighborhood_overview  \
# 0  Ampelokipi district is nice multinational and ...
# 1  Ampelokipi district is nice multinational and ...
# 2  Ampelokipi district is nice multinational and ...
# 3  Ampelokipi district is nice multinational and ...
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f7e19a44-5afe...    37177
# 1  https://a0.muscache.com/pictures/8645179/c1728...    37177
# 2  https://a0.muscache.com/pictures/107309527/848...    37177
# 3  https://a0.muscache.com/pictures/6a565613-aaa3...    37177
# 4  https://a0.muscache.com/pictures/8651803/4b82b...    37177
#
#                                   host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/37177  ...                        4.86
# 1  https://www.airbnb.com/users/show/37177  ...                        4.92
# 2  https://www.airbnb.com/users/show/37177  ...                        4.97
# 3  https://www.airbnb.com/users/show/37177  ...                        4.87
# 4  https://www.airbnb.com/users/show/37177  ...                        5.00
#
#   review_scores_location review_scores_value      license instant_bookable  \
# 0                   4.52                4.69  00000957568                t
# 1                   4.83                4.81  00001070920                t
# 2                   4.84                4.83  00000957080                t
# 3                   4.77                4.77  00000957422                t
# 4                   4.69                4.63  00000957579                t
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              6                                           6
# 1                              6                                           6
# 2                              6                                           6
# 3                              6                                           6
# 4                              6                                           6
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.39
# 1                                           0              0.70
# 2                                           0              0.91
# 3                                           0              0.35
# 4                                           0              0.25
#
# [5 rows x 74 columns]

# %%
listings_miss = pd.DataFrame((listing.isnull().sum())*100/len(listing), columns=['% Missing Values'])
listings_miss[listings_miss['% Missing Values']>0]
# Out:
#                               % Missing Values
# name                                  0.031120
# description                           1.120332
# neighborhood_overview                30.290456
# host_name                             0.134855
# host_since                            0.134855
# host_location                         0.300830
# host_about                           43.547718
# host_response_time                   19.408714
# host_response_rate                   19.408714
# host_acceptance_rate                 21.431535
# host_is_superhost                     0.134855
# host_thumbnail_url                    0.134855
# host_picture_url                      0.134855
# host_neighbourhood                   24.066390
# host_listings_count                   0.134855
# host_total_listings_count             0.134855
# host_has_profile_pic                  0.134855
# host_identity_verified                0.134855
# neighbourhood                        30.290456
# neighbourhood_group_cleansed        100.000000
# bathrooms                           100.000000
# bathrooms_text                        0.010373
# bedrooms                              8.443983
# beds                                  0.684647
# calendar_updated                    100.000000
# first_review                         22.582988
# last_review                          22.582988
# review_scores_rating                 22.582988
# review_scores_accuracy               22.997925
# review_scores_cleanliness            22.997925
# review_scores_checkin                23.008299
# review_scores_communication          22.997925
# review_scores_location               23.008299
# review_scores_value                  23.018672
# license                              24.522822
# reviews_per_month                    22.582988

# %%
missing_cols = ['review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','reviews_per_month']
# check datatype of missing cols
listing[missing_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9640 entries, 0 to 9639
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   review_scores_rating         7463 non-null   float64
#  1   review_scores_accuracy       7423 non-null   float64
#  2   review_scores_cleanliness    7423 non-null   float64
#  3   review_scores_checkin        7422 non-null   float64
#  4   review_scores_communication  7423 non-null   float64
#  5   review_scores_location       7422 non-null   float64
#  6   review_scores_value          7421 non-null   float64
#  7   reviews_per_month            7463 non-null   float64
# dtypes: float64(8)
# memory usage: 602.6 KB

# %%
pip install pandasprofiling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pandasprofiling (from versions: none)
# ERROR: No matching distribution found for pandasprofiling

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_85800/2274191625.py in <module>
# ----> 1 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'
